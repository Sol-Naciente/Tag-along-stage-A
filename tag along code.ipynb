# %%
import numpy as np
import pandas as pd

# %%
csv_df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
csv_df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
csv_df.std()
# Out:
# C:\Users\Sol Naciente\AppData\Local\Temp\ipykernel_10232\4004240314.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_df.std()
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
csv_df.mean()
# Out:
# C:\Users\Sol Naciente\AppData\Local\Temp\ipykernel_10232\1276477327.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_df.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
a = csv_df.groupby('Element')

# %%
a

# %%
csv_df.corr(method='kendall')
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.003807      0.000077  0.016511  0.017399
# Item Code     -0.003807   1.000000     -0.015003  0.092185  0.093783
# Element Code   0.000077  -0.015003      1.000000 -0.002848 -0.005358
# Y2014          0.016511   0.092185     -0.002848  1.000000  0.909291
# Y2015          0.017399   0.093783     -0.005358  0.909291  1.000000
# Y2016          0.014528   0.094614     -0.000947  0.889675  0.908289
# Y2017          0.014069   0.094090      0.001603  0.872313  0.888758
# Y2018          0.015546   0.093288     -0.002801  0.861810  0.875977
#
#                  Y2016     Y2017     Y2018
# Area Code     0.014528  0.014069  0.015546
# Item Code     0.094614  0.094090  0.093288
# Element Code -0.000947  0.001603 -0.002801
# Y2014         0.889675  0.872313  0.861810
# Y2015         0.908289  0.888758  0.875977
# Y2016         1.000000  0.909152  0.887806
# ...

# %%
unique_countries = csv_df.nunique('Area')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'Area'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 unique_countries = csv_df.nunique('Area')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10149, in DataFrame.nunique(self, axis, dropna)
#   10111 def nunique(self, axis: Axis = 0, dropna: bool = True) -> Series:
#   10112     """
#   10113     Count number of distinct elements in specified axis.
#   10114
#    (...)
#   10147     dtype: int64
#   10148     """
# ...
